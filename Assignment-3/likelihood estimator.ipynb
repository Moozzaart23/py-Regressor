# %%
import numpy as np
import scipy.special
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
from mpl_toolkits import mplot3d
import random as rand

# %%
Xright = np.random.uniform(0.6,1,size=(120,1))
Xleft = np.random.uniform(0,0.4,size=(30,1))
Xmiddle = np.random.uniform(0.4,0.6,size=(10,1))

# %%
def normal(X):    
    return X/(max(X)-min(X))

# %%
X = np.append(Xleft,Xright,axis=0)
X = np.append(X,Xmiddle,axis=0)

# %%
X.shape
# Out:
# (160, 1)

# %%
X = np.sort(X,axis=0)

# %%
X
# Out:
# array([[0.00763757],
#        [0.03677064],
#        [0.0698081 ],
#        [0.07253248],
#        [0.10027132],
#        [0.11933433],
#        [0.12291679],
#        [0.13053423],
#        [0.13939204],
#        [0.15158835],
#        [0.162179  ],
#        [0.19173564],
#        [0.2096976 ],
#        [0.21685472],
#        [0.22181567],
#        [0.22703598],
#        [0.24914526],
#        [0.26321293],
#        [0.26976831],
#        [0.32495026],
#        [0.3278269 ],
#        [0.32830581],
#        [0.33303141],
#        [0.33566552],
#        [0.34541368],
#        [0.36658758],
#        [0.37999078],
#        [0.38872679],
#        [0.39097888],
#        [0.39119895],
#        [0.42462675],
#        [0.44772521],
#        [0.4573349 ],
#        [0.50082235],
#        [0.50637418],
#        [0.52592738],
#        [0.54286462],
#        [0.55486794],
#        [0.55795503],
#        [0.58492686],
#        [0.60215371],
#        [0.61026102],
#        [0.61074802],
# ...

# %%
mu_ml=X.mean()

# %%
mu_ml
# Out:
# 0.6782789410976424

# %%
likelihoodB = 1

# %%
for i in range(160): 
    t1 = (mu_ml)**X[i]
    t2 = (1-mu_ml)**(1-X[i])
    likelihoodB = likelihoodB*(t1*t2)

# %%
likelihoodB
# Out:
# array([2.24376022e-44])

# %%
a=rand.random()
b=(3/2*a)

# %%
def update(a,b,X):
    a += len([i for i in X if i>=0.5]) 
    b += len([i for i in X if i<0.5])
    return a,b
def prior(mu_ml,a,b):    
    num1 = scipy.special.gamma(a+b)
    den1 = scipy.special.gamma(a)
    den2 = scipy.special.gamma(b)
    prior = num1/(den1*den2)*(mu_ml**(a-1))*((1-mu_ml)**(b-1)) 
    return prior

# %%
priorB=prior(mu_ml,a,b)

# %%
priorB
# Out:
# 0.8236757823157309

# %%
posteriorB = likelihoodB[0]*priorB

# %%
posteriorB
# Out:
# 1.848130957733514e-44

# %%
posterior = 1
likelihood = 1
temp=[]
mu_mla=0
a=rand.random()
b=(3/2*a)
for i in range(160):
    temp.append(X[i])   
    if (X[i]>=0.5):
        a+=1
    else:
        b+=1
    print(a,b)     
    plt.figure(figsize=(6,4))
    t=np.arange(0,1,0.001)
    plt.plot(t,prior(t,a,b))
    plt.xlabel('mu')
    plt.ylabel('prior')
    plt.savefig(str(i)+"1.png")
    plt.show()
# Out:
# 0.7441071601630947 2.1161607402446423
# c:\users\papam\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:9: RuntimeWarning: divide by zero encountered in power
#   if __name__ == '__main__':
# 0.7441071601630947 3.1161607402446423
# 0.7441071601630947 4.116160740244642
# 0.7441071601630947 5.116160740244642
# 0.7441071601630947 6.116160740244642
# 0.7441071601630947 7.116160740244642
# 0.7441071601630947 8.116160740244641
# 0.7441071601630947 9.116160740244641
# 0.7441071601630947 10.116160740244641
# 0.7441071601630947 11.116160740244641
# 0.7441071601630947 12.116160740244641
# 0.7441071601630947 13.116160740244641
# 0.7441071601630947 14.116160740244641
# 0.7441071601630947 15.116160740244641
# 0.7441071601630947 16.11616074024464
# 0.7441071601630947 17.11616074024464
# 0.7441071601630947 18.11616074024464
# 0.7441071601630947 19.11616074024464
# 0.7441071601630947 20.11616074024464
# 0.7441071601630947 21.11616074024464
# ...

# %%
normal(posteriorA)
# Out:
# array([1.00000000e+00, 3.27812035e-01, 1.08560342e-01, 3.61273323e-02,
#        1.20267403e-02, 4.05496668e-03, 1.37629359e-03, 4.88276298e-04,
#        1.74177344e-04, 6.22313119e-05, 2.32769782e-05, 8.71683987e-06,
#        3.27175701e-06, 1.23295307e-06, 4.64833586e-07, 1.76472763e-07,
#        6.72279590e-08, 2.57362817e-08, 9.89135378e-09, 3.83348798e-09,
#        1.49565036e-09, 5.97648777e-10, 2.39444776e-10, 9.65178222e-11,
#        3.94628537e-11, 1.64562916e-11, 6.87212703e-12, 2.90521288e-12,
#        1.23699390e-12, 5.36706387e-13, 2.34562177e-13, 1.04729173e-13,
#        4.68907686e-14, 2.11710071e-14, 9.75996042e-15, 4.55069236e-15,
#        2.20910954e-15, 1.07438338e-15, 5.33749735e-16, 2.67627362e-16,
#        1.35326144e-16, 6.85189154e-17, 3.49659802e-17, 1.78493018e-17,
#        9.11166846e-18, 4.67448770e-18, 2.41257451e-18, 1.24599906e-18,
#        6.44236155e-19, 3.34674247e-19, 1.73866248e-19, 9.05375576e-20,
# ...

# %%
mu_mla=((mu_mla*i)+X[i])/(i+1)
    t1 = pow(mu_mla,X[i])
    t2 = pow(1-mu_mla,(1-X[i]))
    likelihood = (t1*t2)
    priora =prior(mu_mla,a,b)
    #     posterior = likelihood*priora
#     posteriorA =np.append(posteriorA,[[posterior]])
#     priornext = posterior
